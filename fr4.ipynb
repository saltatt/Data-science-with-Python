# %% [markdown]
# <a href="https://colab.research.google.com/github/saltatt/Data-science-with-Python/blob/main/fr4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd

# %%
df = pandas.read_csv("https://www.football-data.co.uk/mmz4281/2324/EC.csv")
df.head(3)
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  EC  05/08/2023  15:00   Aldershot  Oxford City     5     2   H     3     1
# 1  EC  05/08/2023  15:00  Altrincham  Dag and Red     1     1   D     0     0
# 2  EC  05/08/2023  15:00      Barnet   Hartlepool     3     2   H     1     0
#
#    ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0  ...     2.13 -0.75      2.00      1.80   2.06   1.79     2.08     1.85
# 1  ...     1.94 -0.25      1.68      2.15   1.75   2.12     1.96     2.19
# 2  ...     2.05 -0.25      1.80      2.00   1.87   1.99     1.87     2.04
#
#    AvgCAHH  AvgCAHA
# 0     1.99     1.77
# 1     1.73     2.05
# 2     1.81     1.94
#
# [3 rows x 98 columns]

# %%
df_ger = pandas.read_csv("https://www.football-data.co.uk/mmz4281/2526/D1.csv")
df_ger.head(3)
# Out:
#   Div        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  D1  22/08/2025  19:30  Bayern Munich     RB Leipzig     6     0   H     3
# 1  D1  23/08/2025  14:30  Ein Frankfurt  Werder Bremen     4     1   H     2
# 2  D1  23/08/2025  14:30       Freiburg       Augsburg     1     3   A     0
#
#    HTAG  ... B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     1.98      1.88   1.98   1.93     1.99     1.93     1.90
# 1     0  ...     1.83      2.03   2.02   1.91     1.91     2.03     1.83
# 2     3  ...     1.93      1.93   1.97   1.95     1.97     1.93     1.90
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.86     2.07     1.92
# 1     1.93     1.91     2.06
# 2     1.86     2.03     1.96
#
# [3 rows x 131 columns]

# %%
df_ger= df_ger.rename(columns={
    'FTHG': 'home_goals',
    'FTAG': 'away_goals',
    'FTR':'result',
    'HTHG' : 'home_half_goals',
    'HTAG' : 'away_half_goals'
})

# %%
root = "https://www.football-data.co.uk/mmz4281/"
leagues = ['D1','D2']
frames = []
for league in leagues:
  try:
    df = pandas.read_csv(root + "2324/"+ league + ".csv")
    frames.append(df)
  except Exception as e:
    print(e)

# %%
len(frames)
# Out:
# 2

# %%
frames[1]
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    D2  28/07/2023  19:30         Hamburg     Schalke 04     5     3   H
# 1    D2  29/07/2023  12:00        Hannover     Elversberg     2     2   D
# 2    D2  29/07/2023  12:00  Kaiserslautern       St Pauli     1     2   A
# 3    D2  29/07/2023  12:00       Osnabruck      Karlsruhe     2     3   A
# 4    D2  29/07/2023  12:00           Wehen      Magdeburg     1     1   D
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 301  D2  19/05/2024  14:30        Hannover  Holstein Kiel     1     2   A
# 302  D2  19/05/2024  14:30   Hansa Rostock      Paderborn     1     2   A
# 303  D2  19/05/2024  14:30  Kaiserslautern   Braunschweig     5     0   H
# 304  D2  19/05/2024  14:30       Osnabruck         Hertha     2     1   H
# 305  D2  19/05/2024  14:30           Wehen       St Pauli     1     2   A
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0       1     2  ...     2.62 -0.25      2.05      1.75   2.14   1.78
# 1       1     2  ...     2.39 -0.50      1.95      1.90   1.96   1.94
# 2       0     0  ...     1.66  0.25      1.80      2.05   1.81   2.11
# 3       1     2  ...     2.33  0.25      1.95      1.90   1.98   1.93
# 4       0     1  ...     2.25  0.25      1.90      1.95   1.92   1.99
# ..    ...   ...  ...      ...   ...       ...       ...    ...    ...
# 301     0     2  ...     2.86 -0.25      1.83      2.03   1.78   2.12
# 302     0     0  ...     2.70 -0.25      1.93      1.93   1.95   1.93
# 303     1     0  ...     2.63 -0.75      1.98      1.88   2.01   1.88
# 304     1     1  ...     3.48  0.75      1.88      1.98   1.90   1.98
# 305     1     0  ...     2.38  0.25      1.93      1.93   1.95   1.95
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.14     1.82     2.07     1.75
# 1       2.09     1.95     2.00     1.82
# 2       1.86     2.13     1.77     2.05
# 3       2.03     2.01     1.90     1.90
# 4       1.95     2.03     1.86     1.94
# ..       ...      ...      ...      ...
# 301     1.90     2.17     1.81     2.01
# 302     2.05     1.99     1.97     1.85
# 303     2.12     1.92     1.98     1.85
# 304     1.94     2.02     1.86     1.97
# 305     1.97     1.99     1.91     1.91
#
# [306 rows x 105 columns]

# %%
frames = []
for league in leagues:
  for season in range (15,26):
    season_str = str(season) + str(season + 1)
    try:
      df = pandas.read_csv(root + season_str + "/" + league + ".csv")
      frames.append(df)
    except Exception as e:
      print(e)
len(frames)
# Out:
# 22

# %%
frames[20]
# Out:
#     Div        Date   Time    HomeTeam            AwayTeam  FTHG  FTAG FTR  \
# 0    D2  02/08/2024  19:30     FC Koln             Hamburg     1     2   A
# 1    D2  03/08/2024  12:00    Hannover          Regensburg     2     0   H
# 2    D2  03/08/2024  12:00      Hertha           Paderborn     1     2   A
# 3    D2  03/08/2024  12:00   Karlsruhe            Nurnberg     3     2   H
# 4    D2  03/08/2024  12:00   Magdeburg          Elversberg     0     0   D
# ..   ..         ...    ...         ...                 ...   ...   ...  ..
# 301  D2  18/05/2025  14:30      Hertha            Hannover     1     1   D
# 302  D2  18/05/2025  14:30   Karlsruhe           Paderborn     3     0   H
# 303  D2  18/05/2025  14:30   Magdeburg  Fortuna Dusseldorf     4     2   H
# 304  D2  18/05/2025  14:30  Schalke 04          Elversberg     1     2   A
# 305  D2  18/05/2025  14:30         Ulm     Preußen Münster     2     2   D
#
#      HTHG  HTAG  ... B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0       0     2  ...     1.75      2.05   1.84   2.08     1.95     2.18
# 1       2     0  ...     1.88      1.98   1.88   2.02     1.93     2.02
# 2       0     1  ...     1.83      2.03   1.85   2.06     1.93     2.08
# 3       1     2  ...     1.88      1.98   1.94   1.96     1.94     2.02
# 4       0     0  ...     1.98      1.88   1.98   1.93     2.02     1.94
# ..    ...   ...  ...      ...       ...    ...    ...      ...      ...
# 301     1     1  ...     1.83      1.98   1.86   2.03     1.89     2.05
# 302     0     0  ...     1.98      1.83   2.00   1.89     2.04     1.92
# 303     0     1  ...     1.75      2.05   1.79   2.08     1.85     2.10
# 304     0     1  ...     1.85      1.95   1.88   2.01     1.90     2.02
# 305     1     0  ...     2.05      1.75   2.13   1.76     2.13     1.93
#
#      AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# 0       1.80     2.04     1.87     2.13
# 1       1.88     1.95     1.85     2.13
# 2       1.84     1.99     1.92     2.06
# 3       1.86     1.97     1.95     2.02
# 4       1.92     1.91     1.97     2.00
# ..       ...      ...      ...      ...
# 301     1.82     2.00     1.88     2.12
# 302     1.96     1.86     2.06     1.92
# 303     1.79     2.04     1.84     2.13
# 304     1.85     1.97     1.94     2.03
# 305     2.02     1.80     2.17     1.84
#
# [306 rows x 119 columns]

# %%
dict_coun = {
    'Spanish La Liga' : 'SP1',
    'Spanish Segunda Division' : 'SP2',
    'English Premier League' : 'E0',
    'English League 1' : 'E1',
    'English League 2' : 'E2',
    'German Bundesliga' : 'D1',
    'German 2. Bundesliga' : 'D2',
    'Italian Serie A' : 'I1',
    'Italian Serie B' : 'I2'
       }

# %%
dict_hist_data = {}
for league in dict_coun:
    frames = []
    for season in range(15,26):
        df = pandas.read_csv(root + str(season) + str(season + 1) + "/" + dict_coun[league] + ".csv", encoding = 'latin1')
        df.insert(1,'season', season)
        frames.append(df)
    df_frames = pd.concat(frames)
    dict_hist_data[league] = df_frames

# %%
dict_hist_data['German Bundesliga'].to_csv('german liga.csv')

# %%
df_frames
# Out:
#     Div  season        Date   HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    I2      15    05/09/15     Cesena         Brescia     2     0   H   2.0
# 1    I2      15    06/09/15       Bari          Spezia     4     3   H   2.0
# 2    I2      15    06/09/15    Livorno         Pescara     4     0   H   3.0
# 3    I2      15    06/09/15     Modena         Vicenza     0     1   A   0.0
# 4    I2      15    06/09/15     Novara          Latina     1     1   D   1.0
# ..  ...     ...         ...        ...             ...   ...   ...  ..   ...
# 35  NaN      25  20/09/2025      Monza       Sampdoria     1     0   H   0.0
# 36  NaN      25  20/09/2025    Mantova          Modena     1     3   A   1.0
# 37  NaN      25  21/09/2025  Carrarese        Avellino     3     4   A   2.0
# 38  NaN      25  21/09/2025    Pescara          Empoli     4     0   H   0.0
# 39  NaN      25  21/09/2025     Padova  Virtus Entella     2     1   H   0.0
#
#     HTAG  ... BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA
# 0    0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    2.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ...  ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 35   0.0  ...   3.95  1.83  3.13  4.33  1.85  3.10  3.90  1.85  3.10  3.90
# 36   2.0  ...   2.02  3.40  3.25  2.05  3.30  3.10  2.05  3.30  3.10  2.05
# 37   2.0  ...   3.40  2.25  3.00  3.13  2.15  2.90  3.20  2.15  2.90  3.20
# 38   0.0  ...   2.25  3.00  3.10  2.30  3.00  3.10  2.20  3.00  3.10  2.20
# 39   1.0  ...   2.95  2.63  2.88  2.75  2.50  2.75  2.75  2.50  2.75  2.75
#
# [4048 rows x 181 columns]

# %%
df_frames[(df_frames['Div'] == 'D1') & (df_frames['season'] == 21)].to_csv('german liga.csv')

# %% [markdown]
# pr

# %%
df_frames= df_frames['']
